# %% [markdown]
# # Analysis of the Yelp Dataset
# ## Final Project for Data 620

# %%
import nltk
import matplotlib as plt
import matplotlib.pyplot as py
% matplotlib inline

# %%
import pandas as pd
from pandas.io.json import json_normalize
import io
import json
import seaborn as sns

# %%
from numpy import nan

# %%
path="C:/Users/talha/Documents/Training/CUNY Classes/IS620/Final_project/yelp_dataset"

# %% [markdown]
# ### 1. Business Attributes

# %% [markdown]
# #### 1.1 Data Cleaning

# %%
bus_loc=path+"/business.json"

# %%
bus_loc
# Out:
# 'C:/Users/talha/Documents/Training/CUNY Classes/IS620/Final_project/yelp_dataset/business.json'

# %%
with open(bus_loc, 'rb') as f:
    data = f.readlines()

# remove the trailing "\n" from each line
data = map(lambda x: x.rstrip(), data)

# %%
data_json_str = "[" + ','.join(data) + "]"

# now, load it into pandas
data_df = pd.read_json(data_json_str)

# %%
bus_data=data_df.head(n=25000)

# %%
bus_data.tail(n=5)
# Out:
#                                    address  \
# 24995              2401 E Indian School Rd
# 24996                        4712 W Hwy 74
# 24997  507 Providence Rd, Crescent Corners
# 24998                      1827 Murray Ave
# 24999        163 Spadina Avenue, 3rd Floor
#
#                                               attributes  \
# 24995  {u'BusinessAcceptsCreditCards': u'True', u'Res...
# 24996           {u'BusinessAcceptsCreditCards': u'True'}
# 24997  {u'BusinessParking': u'{'garage': False, 'stre...
# 24998  {u'Alcohol': u'u'none'', u'HasTV': u'True', u'...
# 24999  {u'Alcohol': u''full_bar'', u'HasTV': u'False'...
#
#                   business_id  \
# 24995  3h-mTVH5zmyLQMUGkZwJfA
# 24996  -VR6Kb9j9P2kr5u6zZJhZg
# 24997  p4VmOBPvdsZHxAmsTuMWvQ
# 24998  wUrnir4yQj4Lnta-jdqqxQ
# 24999  EEIz44ewHhOKmfTloAK13g
#
#                                               categories        city  \
# 24995  Grocery, Coffee & Tea, Convenience Stores, Gas...     Phoenix
# 24996  Oil Change Stations, Auto Parts & Supplies, Ca...      Monroe
# 24997  Hair Salons, Barbers, Cosmetics & Beauty Suppl...   Charlotte
# 24998  Specialty Food, Restaurants, Ethnic Food, Midd...  Pittsburgh
# 24999               Bars, Nightlife, Restaurants, French     Toronto
#
#                                                    hours  is_open   latitude  \
# 24995  {u'Monday': u'0:0-0:0', u'Tuesday': u'0:0-0:0'...        1  33.494420
# 24996  {u'Monday': u'9:0-20:0', u'Tuesday': u'9:0-20:...        1  35.048088
# 24997  {u'Monday': u'10:0-20:0', u'Tuesday': u'10:0-2...        1  35.203487
# 24998  {u'Tuesday': u'11:0-22:0', u'Wednesday': u'11:...        0  40.436364
# 24999  {u'Tuesday': u'17:0-0:45', u'Friday': u'17:0-0...        1  43.648539
#
#         longitude              name postal_code  review_count  stars state
# 24995 -112.029729          Circle K       85016             6    2.0    AZ
# 24996  -80.615587  Union County Kia       28110            16    3.0    NC
# 24997  -80.824446         Supercuts       28207            19    3.5    NC
# 24998  -79.922875           Taza 21       15289            53    4.5    PA
# 24999  -79.395937    Alo Restaurant     M5V 2A5           231    4.5    ON

# %%
cats=bus_data['categories'].str.split(',',expand=True)

# %%
cats=cats.rename(columns={0:'ctg1',1:'ctg2',2:'ctg3',3:'ctg4',4:'ctg5',5:'ctg6',6:'ctg7',7:'ctg8'})

# %%
bus_data=bus_data.merge(cats,left_index=True,right_index=True)

# %%
bus_att=bus_data['attributes'].tolist()

# %%
att_detail=pd.DataFrame()
count=[]

# %%
for i in range(len(bus_att)):
    count.append(i)
    if bus_att[i] is None: 
        att_detail=att_detail.append(pd.Series(),ignore_index=True)
    else:
        att_detail=att_detail.append(json_normalize(bus_att[i]),sort='True')

# %%
att_detail.tail(n=5)
# Out:
#   AcceptsInsurance AgesAllowed     Alcohol  \
# 0              NaN         NaN         NaN
# 0              NaN         NaN         NaN
# 0              NaN         NaN         NaN
# 0              NaN         NaN     u'none'
# 0              NaN         NaN  'full_bar'
#
#                                             Ambience BYOB BYOBCorkage  \
# 0                                                NaN  NaN         NaN
# 0                                                NaN  NaN         NaN
# 0                                                NaN  NaN         NaN
# 0  {'romantic': False, 'intimate': False, 'touris...  NaN         NaN
# 0  {'romantic': False, 'intimate': False, 'classy...  NaN         NaN
#
#                                           BestNights BikeParking  \
# 0                                                NaN       False
# 0                                                NaN         NaN
# 0                                                NaN        True
# 0                                                NaN         NaN
# 0  {'monday': False, 'tuesday': False, 'friday': ...        True
#
#   BusinessAcceptsBitcoin BusinessAcceptsCreditCards  ... RestaurantsAttire  \
# 0                    NaN                       True  ...               NaN
# 0                    NaN                       True  ...               NaN
# 0                    NaN                       True  ...               NaN
# 0                    NaN                       True  ...         u'casual'
# 0                    NaN                        NaN  ...         u'dressy'
#
#   RestaurantsDelivery RestaurantsGoodForGroups RestaurantsPriceRange2  \
# 0                 NaN                      NaN                      1
# 0                 NaN                      NaN                    NaN
# 0                 NaN                      NaN                      1
# 0                True                    False                      1
# 0               False                     True                      4
#
#   RestaurantsReservations RestaurantsTableService RestaurantsTakeOut Smoking  \
# 0                     NaN                     NaN                NaN     NaN
# 0                     NaN                     NaN                NaN     NaN
# 0                     NaN                     NaN                NaN     NaN
# 0                   False                     NaN               True     NaN
# 0                    True                    True              False   u'no'
#
#   WheelchairAccessible   WiFi
# 0                  NaN    NaN
# 0                  NaN    NaN
# 0                  NaN    NaN
# 0                  NaN  u'no'
# 0                  NaN  u'no'
#
# [5 rows x 37 columns]

# %%
att_detail['index']=count

# %%
att_detail=att_detail.set_index('index')

# %%
#setup empty dataframe containers
amb_det=pd.DataFrame()
meal_det=pd.DataFrame()
amb_count=[]
meal_count=[]

# %%
# extract detailed data for 'ambience' and 'Good for meal'
for i in range(len(att_detail)):
    amb_count.append(i)
    if pd.isna(att_detail['Ambience'][i]) or (att_detail['Ambience'][i]=='None'): 
        amb_det=amb_det.append(pd.Series(),ignore_index=True)
    else:
        d = att_detail['Ambience'][i]
        d = d.replace('True', "'True'")
        d = d.replace('False',"'False'")
        d = d.replace("'", "\"")
        d = json.loads(d)
        d=pd.DataFrame.from_dict(d,orient='index')
        d=d.transpose()
        amb_det=amb_det.append(d,sort='True')

# %%
amb_det.tail(n=5)
# Out:
#       casual classy  divey hipster intimate romantic touristy trendy upscale
# 24995    NaN    NaN    NaN     NaN      NaN      NaN      NaN    NaN     NaN
# 24996    NaN    NaN    NaN     NaN      NaN      NaN      NaN    NaN     NaN
# 24997    NaN    NaN    NaN     NaN      NaN      NaN      NaN    NaN     NaN
# 0       True  False  False   False    False    False    False  False   False
# 0      False  False  False   False    False    False    False  False    True

# %%
#update the index
amb_det['index']=amb_count
amb_det=amb_det.set_index('index')

# %%
amb_det.tail(n=5)
# Out:
#       casual classy  divey hipster intimate romantic touristy trendy upscale
# index
# 24995    NaN    NaN    NaN     NaN      NaN      NaN      NaN    NaN     NaN
# 24996    NaN    NaN    NaN     NaN      NaN      NaN      NaN    NaN     NaN
# 24997    NaN    NaN    NaN     NaN      NaN      NaN      NaN    NaN     NaN
# 24998   True  False  False   False    False    False    False  False   False
# 24999  False  False  False   False    False    False    False  False    True

# %%
# extract detailed data for 'ambience' and 'Good for meal'
for i in range(len(att_detail)):
    meal_count.append(i)
    if pd.isna(att_detail['GoodForMeal'][i]) or (att_detail['GoodForMeal'][i]=='None'): 
        meal_det=meal_det.append(pd.Series(),ignore_index=True)
    else:
        d = att_detail['GoodForMeal'][i]
        d = d.replace('True', "'True'")
        d = d.replace('False',"'False'")
        d = d.replace("'", "\"")
        d = json.loads(d)
        d=pd.DataFrame.from_dict(d,orient='index')
        d=d.transpose()
        meal_det=meal_det.append(d,sort='True')

# %%
meal_det.head(n=10)
# Out:
#   breakfast brunch dessert dinner latenight lunch
# 0       NaN    NaN     NaN    NaN       NaN   NaN
# 1     False  False   False   True     False  True
# 2     False  False   False   True     False  True
# 3       NaN    NaN     NaN    NaN       NaN   NaN
# 4       NaN    NaN     NaN    NaN       NaN   NaN
# 5       NaN    NaN     NaN    NaN       NaN   NaN
# 6       NaN    NaN     NaN    NaN       NaN   NaN
# 7       NaN    NaN     NaN    NaN       NaN   NaN
# 8       NaN    NaN     NaN    NaN       NaN   NaN
# 9       NaN    NaN     NaN    NaN       NaN   NaN

# %%
#update index 
meal_det['index']=meal_count
meal_det=meal_det.set_index('index')

# %%
#merge ambience and meal data
comb_det=amb_det.merge(meal_det,left_index=True,right_index=True)

# %%
comb_det.tail(n=5)
# Out:
#       casual classy  divey hipster intimate romantic touristy trendy upscale  \
# index
# 24995    NaN    NaN    NaN     NaN      NaN      NaN      NaN    NaN     NaN
# 24996    NaN    NaN    NaN     NaN      NaN      NaN      NaN    NaN     NaN
# 24997    NaN    NaN    NaN     NaN      NaN      NaN      NaN    NaN     NaN
# 24998   True  False  False   False    False    False    False  False   False
# 24999  False  False  False   False    False    False    False  False    True
#
#       breakfast brunch dessert dinner latenight  lunch
# index
# 24995       NaN    NaN     NaN    NaN       NaN    NaN
# 24996       NaN    NaN     NaN    NaN       NaN    NaN
# 24997       NaN    NaN     NaN    NaN       NaN    NaN
# 24998       NaN    NaN     NaN    NaN       NaN    NaN
# 24999     False  False   False   True     False  False

# %%
#merge combined meal and ambience dataframes with attribute detail
att_detail=att_detail.merge(comb_det,left_index=True,right_index=True)

# %%
#vliew all the attributes
att_detail.tail(n=5).transpose()
# Out:
# index                                                                   24995  \
# AcceptsInsurance                                                          NaN
# AgesAllowed                                                               NaN
# Alcohol                                                                   NaN
# Ambience                                                                  NaN
# BYOB                                                                      NaN
# BYOBCorkage                                                               NaN
# BestNights                                                                NaN
# BikeParking                                                             False
# BusinessAcceptsBitcoin                                                    NaN
# BusinessAcceptsCreditCards                                               True
# BusinessParking             {'garage': False, 'street': False, 'validated'...
# ByAppointmentOnly                                                         NaN
# Caters                                                                    NaN
# CoatCheck                                                                 NaN
# Corkage                                                                   NaN
# DietaryRestrictions                                                       NaN
# DogsAllowed                                                               NaN
# DriveThru                                                                 NaN
# GoodForDancing                                                            NaN
# GoodForKids                                                               NaN
# GoodForMeal                                                               NaN
# HairSpecializesIn                                                         NaN
# HappyHour                                                                 NaN
# HasTV                                                                     NaN
# Music                                                                     NaN
# NoiseLevel                                                                NaN
# OutdoorSeating                                                            NaN
# RestaurantsAttire                                                         NaN
# RestaurantsDelivery                                                       NaN
# RestaurantsGoodForGroups                                                  NaN
# RestaurantsPriceRange2                                                      1
# RestaurantsReservations                                                   NaN
# RestaurantsTableService                                                   NaN
# RestaurantsTakeOut                                                        NaN
# Smoking                                                                   NaN
# WheelchairAccessible                                                      NaN
# WiFi                                                                      NaN
# casual                                                                    NaN
# classy                                                                    NaN
# divey                                                                     NaN
# hipster                                                                   NaN
# intimate                                                                  NaN
# romantic                                                                  NaN
# touristy                                                                  NaN
# trendy                                                                    NaN
# upscale                                                                   NaN
# breakfast                                                                 NaN
# brunch                                                                    NaN
# dessert                                                                   NaN
# dinner                                                                    NaN
# latenight                                                                 NaN
# lunch                                                                     NaN
#
# index                      24996  \
# AcceptsInsurance             NaN
# AgesAllowed                  NaN
# Alcohol                      NaN
# Ambience                     NaN
# BYOB                         NaN
# BYOBCorkage                  NaN
# BestNights                   NaN
# BikeParking                  NaN
# BusinessAcceptsBitcoin       NaN
# BusinessAcceptsCreditCards  True
# BusinessParking              NaN
# ByAppointmentOnly            NaN
# Caters                       NaN
# CoatCheck                    NaN
# Corkage                      NaN
# DietaryRestrictions          NaN
# DogsAllowed                  NaN
# DriveThru                    NaN
# GoodForDancing               NaN
# GoodForKids                  NaN
# GoodForMeal                  NaN
# HairSpecializesIn            NaN
# HappyHour                    NaN
# HasTV                        NaN
# Music                        NaN
# NoiseLevel                   NaN
# OutdoorSeating               NaN
# RestaurantsAttire            NaN
# RestaurantsDelivery          NaN
# RestaurantsGoodForGroups     NaN
# RestaurantsPriceRange2       NaN
# RestaurantsReservations      NaN
# RestaurantsTableService      NaN
# RestaurantsTakeOut           NaN
# Smoking                      NaN
# WheelchairAccessible         NaN
# WiFi                         NaN
# casual                       NaN
# classy                       NaN
# divey                        NaN
# hipster                      NaN
# intimate                     NaN
# romantic                     NaN
# touristy                     NaN
# trendy                       NaN
# upscale                      NaN
# breakfast                    NaN
# brunch                       NaN
# dessert                      NaN
# dinner                       NaN
# latenight                    NaN
# lunch                        NaN
#
# index                                                                   24997  \
# AcceptsInsurance                                                          NaN
# AgesAllowed                                                               NaN
# Alcohol                                                                   NaN
# Ambience                                                                  NaN
# BYOB                                                                      NaN
# BYOBCorkage                                                               NaN
# BestNights                                                                NaN
# BikeParking                                                              True
# BusinessAcceptsBitcoin                                                    NaN
# BusinessAcceptsCreditCards                                               True
# BusinessParking             {'garage': False, 'street': False, 'validated'...
# ByAppointmentOnly                                                       False
# Caters                                                                    NaN
# CoatCheck                                                                 NaN
# Corkage                                                                   NaN
# DietaryRestrictions                                                       NaN
# DogsAllowed                                                               NaN
# DriveThru                                                                 NaN
# GoodForDancing                                                            NaN
# GoodForKids                                                              True
# GoodForMeal                                                               NaN
# HairSpecializesIn                                                         NaN
# HappyHour                                                                 NaN
# HasTV                                                                     NaN
# Music                                                                     NaN
# NoiseLevel                                                                NaN
# OutdoorSeating                                                            NaN
# RestaurantsAttire                                                         NaN
# RestaurantsDelivery                                                       NaN
# RestaurantsGoodForGroups                                                  NaN
# RestaurantsPriceRange2                                                      1
# RestaurantsReservations                                                   NaN
# RestaurantsTableService                                                   NaN
# RestaurantsTakeOut                                                        NaN
# Smoking                                                                   NaN
# WheelchairAccessible                                                      NaN
# WiFi                                                                      NaN
# casual                                                                    NaN
# classy                                                                    NaN
# divey                                                                     NaN
# hipster                                                                   NaN
# intimate                                                                  NaN
# romantic                                                                  NaN
# touristy                                                                  NaN
# trendy                                                                    NaN
# upscale                                                                   NaN
# breakfast                                                                 NaN
# brunch                                                                    NaN
# dessert                                                                   NaN
# dinner                                                                    NaN
# latenight                                                                 NaN
# lunch                                                                     NaN
#
# index                                                                   24998  \
# AcceptsInsurance                                                          NaN
# AgesAllowed                                                               NaN
# Alcohol                                                               u'none'
# Ambience                    {'romantic': False, 'intimate': False, 'touris...
# BYOB                                                                      NaN
# BYOBCorkage                                                               NaN
# BestNights                                                                NaN
# BikeParking                                                               NaN
# BusinessAcceptsBitcoin                                                    NaN
# BusinessAcceptsCreditCards                                               True
# BusinessParking             {'garage': False, 'street': True, 'validated':...
# ByAppointmentOnly                                                         NaN
# Caters                                                                    NaN
# CoatCheck                                                                 NaN
# Corkage                                                                   NaN
# DietaryRestrictions                                                       NaN
# DogsAllowed                                                               NaN
# DriveThru                                                                 NaN
# GoodForDancing                                                            NaN
# GoodForKids                                                              True
# GoodForMeal                                                               NaN
# HairSpecializesIn                                                         NaN
# HappyHour                                                                 NaN
# HasTV                                                                    True
# Music                                                                     NaN
# NoiseLevel                                                           u'quiet'
# OutdoorSeating                                                          False
# RestaurantsAttire                                                   u'casual'
# RestaurantsDelivery                                                      True
# RestaurantsGoodForGroups                                                False
# RestaurantsPriceRange2                                                      1
# RestaurantsReservations                                                 False
# RestaurantsTableService                                                   NaN
# RestaurantsTakeOut                                                       True
# Smoking                                                                   NaN
# WheelchairAccessible                                                      NaN
# WiFi                                                                    u'no'
# casual                                                                   True
# classy                                                                  False
# divey                                                                   False
# hipster                                                                 False
# intimate                                                                False
# romantic                                                                False
# touristy                                                                False
# trendy                                                                  False
# upscale                                                                 False
# breakfast                                                                 NaN
# brunch                                                                    NaN
# dessert                                                                   NaN
# dinner                                                                    NaN
# latenight                                                                 NaN
# lunch                                                                     NaN
#
# index                                                                   24999
# AcceptsInsurance                                                          NaN
# AgesAllowed                                                               NaN
# Alcohol                                                            'full_bar'
# Ambience                    {'romantic': False, 'intimate': False, 'classy...
# BYOB                                                                      NaN
# BYOBCorkage                                                               NaN
# BestNights                  {'monday': False, 'tuesday': False, 'friday': ...
# BikeParking                                                              True
# BusinessAcceptsBitcoin                                                    NaN
# BusinessAcceptsCreditCards                                                NaN
# BusinessParking             {'garage': False, 'street': True, 'validated':...
# ByAppointmentOnly                                                         NaN
# Caters                                                                  False
# CoatCheck                                                                True
# Corkage                                                                   NaN
# DietaryRestrictions                                                       NaN
# DogsAllowed                                                               NaN
# DriveThru                                                                 NaN
# GoodForDancing                                                          False
# GoodForKids                                                             False
# GoodForMeal                 {'dessert': False, 'latenight': False, 'lunch'...
# HairSpecializesIn                                                         NaN
# HappyHour                                                               False
# HasTV                                                                   False
# Music                       {'dj': False, 'background_music': True, 'jukeb...
# NoiseLevel                                                         u'average'
# OutdoorSeating                                                          False
# RestaurantsAttire                                                   u'dressy'
# RestaurantsDelivery                                                     False
# RestaurantsGoodForGroups                                                 True
# RestaurantsPriceRange2                                                      4
# RestaurantsReservations                                                  True
# RestaurantsTableService                                                  True
# RestaurantsTakeOut                                                      False
# Smoking                                                                 u'no'
# WheelchairAccessible                                                      NaN
# WiFi                                                                    u'no'
# casual                                                                  False
# classy                                                                  False
# divey                                                                   False
# hipster                                                                 False
# intimate                                                                False
# romantic                                                                False
# touristy                                                                False
# trendy                                                                  False
# upscale                                                                  True
# breakfast                                                               False
# brunch                                                                  False
# dessert                                                                 False
# dinner                                                                   True
# latenight                                                               False
# lunch                                                                   False

# %%
#merge the updated attributes data with the full dataframe
bus_data=bus_data.merge(att_detail,left_index=True,right_index=True)

# %%
#quick view of all the data frame detail
bus_data.tail(n=3).transpose()
# Out:
#                                                                       24997  \
# address                                 507 Providence Rd, Crescent Corners
# attributes                {u'BusinessParking': u'{'garage': False, 'stre...
# business_id                                          p4VmOBPvdsZHxAmsTuMWvQ
# categories                Hair Salons, Barbers, Cosmetics & Beauty Suppl...
# city                                                              Charlotte
# hours                     {u'Monday': u'10:0-20:0', u'Tuesday': u'10:0-2...
# is_open                                                                   1
# latitude                                                            35.2035
# longitude                                                          -80.8244
# name                                                              Supercuts
# postal_code                                                           28207
# review_count                                                             19
# stars                                                                   3.5
# state                                                                    NC
# ctg1                                                            Hair Salons
# ctg2                                                                Barbers
# ctg3                                              Cosmetics & Beauty Supply
# ctg4                                                          Beauty & Spas
# ctg5                                                               Shopping
# ctg6                                                          Hair Stylists
# ctg7                                                      Men's Hair Salons
# ctg8                                                                   None
# 8                                                                      None
# 9                                                                      None
# 10                                                                     None
# 11                                                                     None
# 12                                                                     None
# 13                                                                     None
# 14                                                                     None
# 15                                                                     None
# ...                                                                     ...
# HappyHour                                                               NaN
# HasTV                                                                   NaN
# Music                                                                   NaN
# NoiseLevel                                                              NaN
# OutdoorSeating                                                          NaN
# RestaurantsAttire                                                       NaN
# RestaurantsDelivery                                                     NaN
# RestaurantsGoodForGroups                                                NaN
# RestaurantsPriceRange2                                                    1
# RestaurantsReservations                                                 NaN
# RestaurantsTableService                                                 NaN
# RestaurantsTakeOut                                                      NaN
# Smoking                                                                 NaN
# WheelchairAccessible                                                    NaN
# WiFi                                                                    NaN
# casual                                                                  NaN
# classy                                                                  NaN
# divey                                                                   NaN
# hipster                                                                 NaN
# intimate                                                                NaN
# romantic                                                                NaN
# touristy                                                                NaN
# trendy                                                                  NaN
# upscale                                                                 NaN
# breakfast                                                               NaN
# brunch                                                                  NaN
# dessert                                                                 NaN
# dinner                                                                  NaN
# latenight                                                               NaN
# lunch                                                                   NaN
#
#                                                                       24998  \
# address                                                     1827 Murray Ave
# attributes                {u'Alcohol': u'u'none'', u'HasTV': u'True', u'...
# business_id                                          wUrnir4yQj4Lnta-jdqqxQ
# categories                Specialty Food, Restaurants, Ethnic Food, Midd...
# city                                                             Pittsburgh
# hours                     {u'Tuesday': u'11:0-22:0', u'Wednesday': u'11:...
# is_open                                                                   0
# latitude                                                            40.4364
# longitude                                                          -79.9229
# name                                                                Taza 21
# postal_code                                                           15289
# review_count                                                             53
# stars                                                                   4.5
# state                                                                    PA
# ctg1                                                         Specialty Food
# ctg2                                                            Restaurants
# ctg3                                                            Ethnic Food
# ctg4                                                         Middle Eastern
# ctg5                                                                   Food
# ctg6                                                                   None
# ctg7                                                                   None
# ctg8                                                                   None
# 8                                                                      None
# 9                                                                      None
# 10                                                                     None
# 11                                                                     None
# 12                                                                     None
# 13                                                                     None
# 14                                                                     None
# 15                                                                     None
# ...                                                                     ...
# HappyHour                                                               NaN
# HasTV                                                                  True
# Music                                                                   NaN
# NoiseLevel                                                         u'quiet'
# OutdoorSeating                                                        False
# RestaurantsAttire                                                 u'casual'
# RestaurantsDelivery                                                    True
# RestaurantsGoodForGroups                                              False
# RestaurantsPriceRange2                                                    1
# RestaurantsReservations                                               False
# RestaurantsTableService                                                 NaN
# RestaurantsTakeOut                                                     True
# Smoking                                                                 NaN
# WheelchairAccessible                                                    NaN
# WiFi                                                                  u'no'
# casual                                                                 True
# classy                                                                False
# divey                                                                 False
# hipster                                                               False
# intimate                                                              False
# romantic                                                              False
# touristy                                                              False
# trendy                                                                False
# upscale                                                               False
# breakfast                                                               NaN
# brunch                                                                  NaN
# dessert                                                                 NaN
# dinner                                                                  NaN
# latenight                                                               NaN
# lunch                                                                   NaN
#
#                                                                       24999
# address                                       163 Spadina Avenue, 3rd Floor
# attributes                {u'Alcohol': u''full_bar'', u'HasTV': u'False'...
# business_id                                          EEIz44ewHhOKmfTloAK13g
# categories                             Bars, Nightlife, Restaurants, French
# city                                                                Toronto
# hours                     {u'Tuesday': u'17:0-0:45', u'Friday': u'17:0-0...
# is_open                                                                   1
# latitude                                                            43.6485
# longitude                                                          -79.3959
# name                                                         Alo Restaurant
# postal_code                                                         M5V 2A5
# review_count                                                            231
# stars                                                                   4.5
# state                                                                    ON
# ctg1                                                                   Bars
# ctg2                                                              Nightlife
# ctg3                                                            Restaurants
# ctg4                                                                 French
# ctg5                                                                   None
# ctg6                                                                   None
# ctg7                                                                   None
# ctg8                                                                   None
# 8                                                                      None
# 9                                                                      None
# 10                                                                     None
# 11                                                                     None
# 12                                                                     None
# 13                                                                     None
# 14                                                                     None
# 15                                                                     None
# ...                                                                     ...
# HappyHour                                                             False
# HasTV                                                                 False
# Music                     {'dj': False, 'background_music': True, 'jukeb...
# NoiseLevel                                                       u'average'
# OutdoorSeating                                                        False
# RestaurantsAttire                                                 u'dressy'
# RestaurantsDelivery                                                   False
# RestaurantsGoodForGroups                                               True
# RestaurantsPriceRange2                                                    4
# RestaurantsReservations                                                True
# RestaurantsTableService                                                True
# RestaurantsTakeOut                                                    False
# Smoking                                                               u'no'
# WheelchairAccessible                                                    NaN
# WiFi                                                                  u'no'
# casual                                                                False
# classy                                                                False
# divey                                                                 False
# hipster                                                               False
# intimate                                                              False
# romantic                                                              False
# touristy                                                              False
# trendy                                                                False
# upscale                                                                True
# breakfast                                                             False
# brunch                                                                False
# dessert                                                               False
# dinner                                                                 True
# latenight                                                             False
# lunch                                                                 False
#
# [91 rows x 3 columns]

# %% [markdown]
# #### 1.2 Business Data Summary & Study Area Selection

# %%
bus_data[['state','city','business_id']].groupby('state').count()
# Out:
#        city  business_id
# state
# AB     1017         1017
# AZ     7347         7347
# CA        2            2
# FL        1            1
# IL      254          254
# NC     1834         1834
# NM        1            1
# NV     4747         4747
# NY        3            3
# OH     1988         1988
# ON     4288         4288
# PA     1482         1482
# QC     1194         1194
# SC      137          137
# TX        1            1
# UT        1            1
# WI      703          703

# %%
bus_data.filter(items=['state','city','business_id']).groupby(['state','city']).count()
# Out:
#                          business_id
# state city
# AB    Airdrie                     17
#       Alberta                      1
#       Balzac                       1
#       Calgary                    980
#       Chestermere                  7
#       Edgemont                     1
#       Edmonton                     1
#       Evergreen                    1
#       Northwest Calgary            1
#       Rocky View                   4
#       Rocky View County            2
#       Rockyview                    1
# AZ    Ahwatukee                    2
#       Anthem                       6
#       Apache Junction              4
#       Arizona                      1
#       Avondale                    94
#       Buckeye                      8
#       Carefree                     9
#       Cave Creek                  47
#       Chandler                   567
#       El Mirage                    9
#       Fort McDowell                1
#       Fort Mcdowell                1
#       Fountain Hills              40
#       Gilbert                    430
#       Glendale                   495
#       Glendale Az                  1
#       Goodyear                   110
#       Guadalupe                    1
# ...                              ...
# SC    Fort Mill                   78
#       Indian Land                 12
#       Lake Wylie                   3
#       Rock Hill                   39
#       Rock Hill SC                 1
#       Tega Cay                     2
# TX    Phoenix                      1
# UT    Draper                       1
# WI    Belleville                   5
#       Cottage Grove                5
#       Cross Plains                 3
#       De Forest                    2
#       DeForest                     2
#       Deerfield                    1
#       Deforest                     1
#       Fitchburg                   30
#       Madison                    477
#       Mc Farland                   5
#       McFarland                    4
#       Middleton                   42
#       Monona                      19
#       Mount Horeb                  6
#       Oregon                       8
#       Paoli                        1
#       Sauk City                    1
#       Stoughton                   19
#       Sun Prairie                 34
#       Verona                      22
#       Waunakee                    14
#       Windsor                      2
#
# [545 rows x 1 columns]

# %%
#check the top counts by City and region
bus_data[['state','city','business_id']][bus_data["state"]=='OH'].groupby(['state','city']).count()
# Out:
#                             business_id
# state city
# OH    Akron                          66
#       Amherst                        13
#       Aurora                         19
#       Avon                           26
#       Avon Lake                      15
#       Bainbridge                      1
#       Barberton                       1
#       Bay Village                     7
#       Beachwood                      39
#       Bedford                        15
#       Bedford Heights                 2
#       Bedford Hts                     1
#       Bedford Hts.                    1
#       Berea                          13
#       Boston Heights                  1
#       Bratenahl                       2
#       Brecksville                    13
#       Broadview Heights              15
#       Brook Park                     10
#       Brooklyn                        8
#       Brookpark                       1
#       Brunswick                      25
#       Burton                          6
#       Chagrin Falls                  23
#       Chardon                        10
#       Chesterland                    10
#       Cleveland                     473
#       Cleveland Height                1
#       Cleveland Heights              23
#       Cleveland Hghts.                1
# ...                                 ...
#       Richmond Heights                4
#       Rocky River                    38
#       Sagamore Hills                  3
#       Seven Hills                     5
#       Shaker Heights                  5
#       Shaker Hts                      1
#       Sheffield Lake                  2
#       Sheffield Village               3
#       Solon                          29
#       South Euclid                   10
#       Stow                           28
#       Streetsboro                    24
#       Strongsville                   65
#       Tallmadge                       8
#       Tremont                         1
#       Twinsburg                      10
#       University Heights              7
#       Valley View                     1
#       Wadsworth                       5
#       Warrensville Heights            7
#       Warrensville Hts                1
#       Wellington                      1
#       West Lake                       1
#       Westlake                       58
#       Wickliffe                       5
#       Willoughby                     43
#       Willoughby Hills                2
#       Willowick                      12
#       Woodmere                        8
#       kirtland                        1
#
# [126 rows x 1 columns]

# %%
#check the top counts by City and region for Arizona
bus_data[['state','city','business_id']][bus_data["state"]=='AZ'].groupby(['state','city']).count()
# Out:
#                            business_id
# state city
# AZ    Ahwatukee                      2
#       Anthem                         6
#       Apache Junction                4
#       Arizona                        1
#       Avondale                      94
#       Buckeye                        8
#       Carefree                       9
#       Cave Creek                    47
#       Chandler                     567
#       El Mirage                      9
#       Fort McDowell                  1
#       Fort Mcdowell                  1
#       Fountain Hills                40
#       Gilbert                      430
#       Glendale                     495
#       Glendale Az                    1
#       Goodyear                     110
#       Guadalupe                      1
#       Higley                         6
#       Laveen                        15
#       Laveen Village                 1
#       Litchfield                     1
#       Litchfield Park               26
#       Litchfield park                1
#       Mesa                         763
#       Old Town Scottsdale            1
#       PHOENIX                        3
#       Paradise Valley               18
#       Pasadena                       1
#       Peoria                       231
#       Phoenix                     2461
#       Phoenix                        1
#       Phoenix,                       1
#       Queen Creek                   14
#       Rio Verde                      1
#       SCOTTSDALE                     1
#       SURPRISE                       1
#       Scottsdale                  1166
#       Somerton                       1
#       Sun City                      32
#       Sun City West                 13
#       Sun Lakes                      3
#       Surprise                     135
#       Tempe                        587
#       Tolleson                      23
#       Valleywide                     1
#       Waddell                        2
#       Youngtown                      8
#       glendale                       1
#       phoenix                        1
#       ​Chandler                      1

# %% [markdown]
# Based on inspection the all the cities in Arizona are part of the larger Phoenix metro area - including cities such as Mesa, Goodyear, Tempe, Scottsdale and others.
# After reviewing the counts, it seems that the larger Phoenix area would have a large enough dataset to be interesting.

# %%
#subset the data for the greater Phoenix area
az_data=bus_data[bus_data["state"]=='AZ']

# %%
az_data.shape
# Out:
# (4402, 90)

# %%
#create a copy of the index to have an explicit column for the index
az_data.index.name='index'

# %%
index=az_data.index

# %%
az_data.loc[:,'index']=index

# %%
#drop columns that are not needed
az_data.drop(['ctg7','ctg8','attributes','categories',8,9,10,11,12,13,14,15],axis=1,inplace=True)

# %%
az_data.shape
# Out:
# (4402, 79)

# %% [markdown]
# #### 1.3 Selection of Businesses related to the Food Industry
# The yelp data contains categories of businesses. Varying degrees of detail are provided and the categories are not consistent throughout. For example, category 1 is typically the more detailed, "Burgers" with category 2, listed as "Restuarants". However, this not always the case and there some cases where category 1 is Resturants and category 2 is "Restuarants". Below we check and confirm these

# %%
# filter out the categories and pick only restaurants
# since there are multiple categories, check and confirm that all
az_data[['name','address','city','ctg1','ctg2','ctg3','index']].set_index('ctg1').filter(like='Restaurants',axis=0).groupby('ctg2').count()
# Out:
#                           name  address  city  ctg3  index
# ctg2
#  Acai Bowls                  1        1     1     1      1
#  Active Life                 1        1     1     1      1
#  African                     1        1     1     0      1
#  American (New)              9        9     9     5      9
#  American (Traditional)     10       10    10     7     10
#  Arts & Entertainment        2        2     2     2      2
#  Bakeries                    1        1     1     1      1
#  Barbeque                    7        7     7     2      7
#  Bars                        7        7     7     7      7
#  Beer                        2        2     2     2      2
#  Breakfast & Brunch          7        7     7     6      7
#  Bubble Tea                  1        1     1     1      1
#  Buffets                     3        3     3     2      3
#  Burgers                    11       11    11     7     11
#  Cafes                       2        2     2     1      2
#  Casinos                     1        1     1     1      1
#  Chicken Wings               1        1     1     1      1
#  Chinese                    10       10    10     6     10
#  Coffee & Tea                3        3     3     3      3
#  Coffee Roasteries           1        1     1     1      1
#  Comfort Food                1        1     1     1      1
#  Delis                       2        2     2     1      2
#  Diners                      1        1     1     1      1
#  Donuts                      1        1     1     1      1
#  Fast Food                  15       15    15    14     15
#  Fish & Chips                2        2     2     1      2
#  Fitness & Instruction       1        1     1     1      1
#  Food                       15       15    15    15     15
#  Food Stands                 1        1     1     1      1
#  Gluten-Free                 1        1     1     1      1
# ...                        ...      ...   ...   ...    ...
#  Hot Dogs                    2        2     2     2      2
#  Indian                      2        2     2     1      2
#  Italian                     5        5     5     4      5
#  Japanese                    9        9     9     2      9
#  Juice Bars & Smoothies      1        1     1     1      1
#  Kebab                       1        1     1     1      1
#  Korean                      1        1     1     0      1
#  Latin American              2        2     2     1      2
#  Mediterranean               2        2     2     2      2
#  Mexican                    33       33    33    10     33
#  Middle Eastern              1        1     1     0      1
#  Nightlife                   3        3     3     3      3
#  Noodles                     1        1     1     0      1
#  Pizza                      14       14    14     5     14
#  Puerto Rican                1        1     1     1      1
#  Religious Organizations     1        1     1     1      1
#  Salad                       2        2     2     2      2
#  Sandwiches                 12       12    12     7     12
#  Seafood                     4        4     4     2      4
#  Soul Food                   1        1     1     1      1
#  Spanish                     1        1     1     0      1
#  Sports Bars                 2        2     2     2      2
#  Steakhouses                 1        1     1     1      1
#  Sushi Bars                  2        2     2     1      2
#  Szechuan                    1        1     1     1      1
#  Tacos                       1        1     1     1      1
#  Tex-Mex                     3        3     3     1      3
#  Vegan                       1        1     1     0      1
#  Vegetarian                  1        1     1     1      1
#  Vietnamese                  4        4     4     1      4
#
# [65 rows x 5 columns]

# %%
az_data[['name','address','city','ctg1','ctg2','ctg3','index']].set_index('ctg2').filter(like='Restaurants',axis=0).groupby('ctg1').count()
# Out:
#                            name  address  city  ctg3  index
# ctg1
# American (New)               11       11    11     6     11
# American (Traditional)        9        9     9     4      9
# Asian Fusion                  3        3     3     3      3
# Bagels                        2        2     2     2      2
# Barbeque                      2        2     2     1      2
# Bars                          2        2     2     2      2
# Basque                        1        1     1     1      1
# Breakfast & Brunch            6        6     6     4      6
# Buffets                       2        2     2     0      2
# Burgers                      10       10    10     7     10
# Cafes                         3        3     3     3      3
# Cajun/Creole                  1        1     1     0      1
# Chicken Wings                 5        5     5     3      5
# Chinese                      14       14    14     1     14
# Coffee & Tea                  3        3     3     3      3
# Conveyor Belt Sushi           1        1     1     1      1
# Cuban                         1        1     1     1      1
# Delis                         5        5     5     3      5
# Diners                        1        1     1     1      1
# Event Planning & Services     1        1     1     1      1
# Fast Food                    15       15    15    13     15
# Filipino                      1        1     1     1      1
# Food                         21       21    21    21     21
# Food Stands                   1        1     1     0      1
# Gastropubs                    1        1     1     1      1
# Gluten-Free                   3        3     3     3      3
# Greek                         1        1     1     0      1
# Grocery                       1        1     1     1      1
# Hotels                        1        1     1     1      1
# Ice Cream & Frozen Yogurt     1        1     1     1      1
# Indian                        2        2     2     1      2
# Italian                       3        3     3     2      3
# Japanese                      7        7     7     5      7
# Jazz & Blues                  1        1     1     1      1
# Korean                        1        1     1     1      1
# Kosher                        1        1     1     0      1
# Mediterranean                 5        5     5     4      5
# Mexican                      31       31    31     7     31
# Middle Eastern                2        2     2     2      2
# New Mexican Cuisine           2        2     2     2      2
# Nightlife                     2        2     2     2      2
# Pakistani                     1        1     1     1      1
# Peruvian                      1        1     1     1      1
# Pizza                        13       13    13     1     13
# Real Estate                   1        1     1     1      1
# Salad                         3        3     3     3      3
# Sandwiches                   11       11    11    10     11
# Seafood                       8        8     8     6      8
# Soul Food                     1        1     1     1      1
# Soup                          1        1     1     1      1
# Specialty Food                1        1     1     1      1
# Sports Bars                   3        3     3     3      3
# Steakhouses                   5        5     5     1      5
# Sushi Bars                    1        1     1     1      1
# Thai                          3        3     3     1      3
# Turkish                       1        1     1     0      1
# Vegetarian                    1        1     1     1      1
# Vietnamese                    4        4     4     1      4

# %%
az_data[['name','address','city','ctg1','ctg2','ctg3','index']].set_index('ctg3').filter(like='Restaurants',axis=0).groupby('ctg2').count()
# Out:
#                             name  address  city  ctg1  index
# ctg2
#  American (New)                7        7     7     7      7
#  American (Traditional)        4        4     4     4      4
#  Arts & Crafts                 1        1     1     1      1
#  Arts & Entertainment          1        1     1     1      1
#  Bakeries                      1        1     1     1      1
#  Barbeque                      2        2     2     2      2
#  Bars                          3        3     3     3      3
#  Breakfast & Brunch            6        6     6     6      6
#  Buffets                       1        1     1     1      1
#  Burgers                      11       11    11    11     11
#  Cafes                         1        1     1     1      1
#  Candy Stores                  1        1     1     1      1
#  Chicken Wings                 3        3     3     3      3
#  Chinese                       2        2     2     2      2
#  Cocktail Bars                 2        2     2     2      2
#  Coffee & Tea                  2        2     2     2      2
#  Comfort Food                  2        2     2     2      2
#  Delis                         3        3     3     3      3
#  Desserts                      2        2     2     2      2
#  Diners                        4        4     4     4      4
#  Donuts                        1        1     1     1      1
#  Event Planning & Services     1        1     1     1      1
#  Fast Food                    12       12    12    12     12
#  Food                         12       12    12    12     12
#  Food Delivery Services        2        2     2     2      2
#  French                        1        1     1     1      1
#  Gastropubs                    1        1     1     1      1
#  Gluten-Free                   1        1     1     1      1
#  Greek                         2        2     2     2      2
#  Grocery                       1        1     1     1      1
#  Hawaiian                      1        1     1     1      1
#  Indian                        1        1     1     1      1
#  Irish                         1        1     1     1      1
#  Italian                       7        7     7     7      7
#  Japanese                      4        4     4     4      4
#  Latin American                1        1     1     1      1
#  Local Flavor                  1        1     1     1      1
#  Mexican                       5        5     5     5      5
#  Nightlife                     7        7     7     7      7
#  Pasta Shops                   1        1     1     1      1
#  Pizza                         4        4     4     4      4
#  Professional Services         1        1     1     1      1
#  Salad                         1        1     1     1      1
#  Sandwiches                    9        9     9     9      9
#  Seafood                       2        2     2     2      2
#  Soup                          3        3     3     3      3
#  Sports Bars                   2        2     2     2      2
#  Street Vendors                1        1     1     1      1
#  Sushi Bars                    2        2     2     2      2
#  Tex-Mex                       2        2     2     2      2
#  Thai                          3        3     3     3      3
#  Vegan                         1        1     1     1      1

# %%
az_data[['name','address','city','ctg1','index','ctg2','ctg3']].set_index('ctg1').filter(like='Restaurants',axis=0).count()
# Out:
#                                    name                           address  \
# ctg1
# Restaurants                   Taco Bell           2450 E Indian School Rd
# Restaurants  Vals Getaway DES Cafeteria                  1789 W Jefferson
# Restaurants           New Mexican Grill          3140 S Gilbert Rd, Ste 3
# Restaurants              Sushi Mocorito  3415 West Glendale Ave, Bldg 25A
# Restaurants      Oregano's Pizza Bistro               1008 E Camelback Rd
#
#                  city  count                 ctg2         ctg3
# ctg1
# Restaurants   Phoenix     11   Breakfast & Brunch      Mexican
# Restaurants   Phoenix    133                 Food        Cafes
# Restaurants  Chandler    146              Mexican         None
# Restaurants   Phoenix    181              Mexican   Sushi Bars
# Restaurants   Phoenix    273                Pizza   Sandwiches

# %%
az_data[['name','address','city','ctg1','index','ctg2','ctg3']].set_index('ctg3').filter(like='Restaurants',axis=0).count()
# Out:
#                                     name           address        city  \
# ctg3
#  Restaurants             Nishikawa Ramen     1909 E Ray Rd    Chandler
#  Restaurants                Panera Bread  88 E Ocotillo Rd    Chandler
#  Restaurants  Arbys Restaurant Higley Rd  1927 N Higley Rd        Mesa
#  Restaurants                      Subway   15508 W Bell Rd    Surprise
#  Restaurants                    Eggstasy  6990 E Shea Blvd  Scottsdale
#
#                       ctg1  count                 ctg2
# ctg3
#  Restaurants  Asian Fusion    346             Japanese
#  Restaurants          Food    381           Sandwiches
#  Restaurants    Sandwiches    415            Fast Food
#  Restaurants    Sandwiches    544            Fast Food
#  Restaurants        Diners    593   Breakfast & Brunch

# %%
az_data[['name','address','city','ctg1','index','ctg2','ctg3']].set_index('ctg2').filter(like='Restaurants',axis=0).count()

# %%
az_data.index.name
# Out:
# 'count'

# %%
import numpy as np
df_d = pd.DataFrame(np.arange(12).reshape(3,4),columns=['A', 'B', 'C', 'D'])

# %%
df_d
# Out:
#    A  B   C   D
# 0  0  1   2   3
# 1  4  5   6   7
# 2  8  9  10  11

# %%
df_d['A'][df.loc[:,'A']==4]=400

# %%
df_d
# Out:
#    A  B   C   D
# 0  0  1   2   3
# 1  4  5   6   7
# 2  8  9  10  11

# %%
df_d=df_d.append(pd.Series(),ignore_index=True)

# %%
df_d
# Out:
#      A    B     C     D
# 0  0.0  1.0   2.0   3.0
# 1  4.0  5.0   6.0   7.0
# 2  8.0  9.0  10.0  11.0
# 3  NaN  NaN   NaN   NaN

# %% [markdown]
# ### References:
# 1. https://stackoverflow.com/questions/35588515/json-opening-yelp-data-challenges-data-set
# 2. https://stackoverflow.com/questions/43624065/yelp-data-file-type
# 3. https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.io.json.json_normalize.html#pandas.io.json.json_normalize
# 4. https://stackoverflow.com/questions/988228/convert-a-string-representation-of-a-dictionary-to-a-dictionary
# 5. https://github.com/kylegilde/NLP-and-Text-Mining-in-Python/tree/master/Classifying-Yelp-Reviews
# 6. https://github.com/nobieyi00/CUNY-SPS-DATA620/blob/master/FINAL_PROJECT/Data620_final_proj.ipynb
# 7. https://github.com/raghu74us/DATA-620/blob/master/FinalProject/DATA%20620%20Final%20Project.ipynb
# 8. https://github.com/jonathan1987/DATA620/blob/master/FinalProject/Final_project_notebook.ipynb
# 9. https://www.datacamp.com/community/tutorials/text-analytics-beginners-nltk
